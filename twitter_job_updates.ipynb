# %%
# installing ntscraper
pip install ntscraper

# %%
# import pandas and nitter
import pandas as pd
from ntscraper import Nitter

# %%
# get instances from nitter for scraping
scraper = Nitter(log_level = 1,skip_instance_check= False)
# Out:
# Testing instances:  13%|███                     | 10/77 [00:21<02:55,  2.62s/it]
# 16-Apr-24 17:50:30 - Certificate did not match expected hostname: nitter.nl. Certificate: {'subject': ((('commonName', 'invidious.nl'),),), 'issuer': ((('countryName', 'US'),), (('organizationName', "Let's Encrypt"),), (('commonName', 'R3'),)), 'version': 3, 'serialNumber': '0324F83ECE64674709BEC8F5D3FE821FBD5E', 'notBefore': 'Apr  5 09:03:34 2024 GMT', 'notAfter': 'Jul  4 09:03:33 2024 GMT', 'subjectAltName': (('DNS', 'invidious.nl'), ('DNS', 'www.invidious.nl')), 'OCSP': ('http://r3.o.lencr.org',), 'caIssuers': ('http://r3.i.lencr.org/',)}
# Testing instances:  92%|██████████████████████▏ | 71/77 [02:56<00:58,  9.72s/it]
# ...

# %%
# import datetime functions for getting everyday's data
from datetime import datetime, timedelta

# Initialize Nitter client

# Get current date and previous day's date
current_date = datetime.now().date()
previous_date = current_date - timedelta(days=1)

since_date = current_date.strftime("%Y-%m-%d")

# %%
# getting data from remoteok account
job_posting_acc = scraper.get_tweets("RemoteOK",mode="user", since=since_date)
# Out:
# 16-Apr-24 17:54:03 - No instance specified, using random instance https://nitter.esmailelbob.xyz
# 16-Apr-24 17:54:09 - Current stats for RemoteOK: 20 tweets, 0 threads...
# 16-Apr-24 17:54:13 - Current stats for RemoteOK: 27 tweets, 0 threads...
# 16-Apr-24 17:54:15 - Empty page on https://nitter.esmailelbob.xyz

# %%
from pprint import pprint

# %%
pprint(tweets)
# Out:
# {'threads': [],
#  'tweets': [{'date': 'May 21, 2021 · 12:17 PM UTC',
#              'external-link': '',
#              'gifs': [],
#              'is-pinned': True,
#              'is-retweet': False,
#              'link': 'https://twitter.com/RemoteOK/status/1395715477033291781#m',
#              'pictures': ['https://pbs.twimg.com/media/E16TuD1VcAYSCuz.jpg'],
#              'quoted-post': {},
#              'replying-to': [],
#              'stats': {'comments': 112,
#                        'likes': 176,
#                        'quotes': 3,
#                        'retweets': 19},
#              'text': '👩\u200d⚕️ 🏥 SafetyWing now offers the first global '
#                      'health insurance for remote workers and nomads  💯 A '
#                      'fully-equipped health insurance made for remote workers '
#                      'and nomads who spend as much time abroad as they please  '
#                      '👉 https://remoteok.io/nomad-health',
# ...

# %%
# getting data from whatlayoff account
layoff_acc = scraper.get_tweets("WhatLayoff",mode="user",since = since_date)
# Out:
# 16-Apr-24 17:54:42 - No instance specified, using random instance https://nitter.esmailelbob.xyz
# 16-Apr-24 17:54:48 - Current stats for WhatLayoff: 20 tweets, 0 threads...
# 16-Apr-24 17:54:53 - Current stats for WhatLayoff: 23 tweets, 0 threads...
# 16-Apr-24 17:54:55 - Empty page on https://nitter.esmailelbob.xyz

# %%
# function to get the scraped data into dataframe and into csv's
def extract_tweet_data(a):

    data = {
        'link': [],
        'text': [],
        'user': [],
        'likes': [],
        'quotes': [],
        'retweets': [],
        'comments': []
    }

    for tweet in a['tweets']:
        data['link'].append(tweet['link'])
        data['text'].append(tweet['text'])
        data['user'].append(tweet['user']['name'])
        data['likes'].append(tweet['stats']['likes'])
        data['quotes'].append(tweet['stats']['quotes'])
        data['retweets'].append(tweet['stats']['retweets'])
        data['comments'].append(tweet['stats']['comments']) 
    df = pd.DataFrame(data)
    return df

# %%
remote_ok= extract_tweet_data(job_posting_acc)
remote_ok.to_csv('/Users/dheerajreddyk/Desktop/Jobs/Projects/remote_ok.csv')

# %%
layoff_acc=extract_tweet_data(layoff_acc)
layoff_acc.to_csv('/Users/dheerajreddyk/Desktop/Jobs/Projects/whatlayoff.csv')
